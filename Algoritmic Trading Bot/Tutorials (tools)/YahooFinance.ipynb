# %%
import yfinance as yf

data = yf.download(
    "AAPL",
    period="5d",
    interval="1m"
)

data.head()
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Datetime
# 2023-06-20 09:30:00-04:00  184.410004  184.919998  184.410004  184.779999
# 2023-06-20 09:31:00-04:00  184.779999  185.268799  184.770004  185.050003
# 2023-06-20 09:32:00-04:00  185.039993  185.479996  185.020004  185.380005
# 2023-06-20 09:33:00-04:00  185.375000  185.662003  185.270004  185.559998
# 2023-06-20 09:34:00-04:00  185.540100  185.779999  185.520004  185.757599
#
#                             Adj Close   Volume
# Datetime
# 2023-06-20 09:30:00-04:00  184.779999  2006473
# 2023-06-20 09:31:00-04:00  185.050003   451946
# 2023-06-20 09:32:00-04:00  185.380005   258712
# 2023-06-20 09:33:00-04:00  185.559998   274272
# 2023-06-20 09:34:00-04:00  185.757599   273213

# %%
data = yf.download('AAPL','2016-01-01','2019-08-01')

# Import the plotting library
import matplotlib.pyplot as plt
# %matplotlib inline

# Plot the close price of the AAPL
data['Adj Close'].plot()
# Out:
# [*********************100%***********************]  1 of 1 completed
# <Axes: xlabel='Date'>

# %%
import pandas as pd
tickers_list = ['AAPL', 'WMT', 'IBM', 'MU', 'BA', 'AXP']

# Fetch the data
data = yf.download(tickers_list,'2015-1-1')['Adj Close']

# Print first 5 rows of the data
print(data.head())
# Out:
# [*********************100%***********************]  6 of 6 completed
#                  AAPL        AXP          BA         IBM         MU        WMT
# Date
# 2015-01-02  24.531765  81.897896  113.657219  106.693787  34.329182  71.685669
# 2015-01-05  23.840668  79.732040  112.870056  105.014969  33.370930  71.477036
# 2015-01-06  23.842911  78.032799  111.540619  102.750221  32.471947  72.027809
# 2015-01-07  24.177238  79.737038  113.272354  102.078682  31.711277  73.938873
# 2015-01-08  25.106184  80.867317  115.275269  104.297379  33.262257  75.499458

# %%
((data.pct_change()+1).cumprod()).plot(figsize=(10, 7))

# Show the legend
plt.legend()

# Define the label for the title of the figure
plt.title("Returns", fontsize=16)

# Define the labels for x-axis and y-axis
plt.ylabel('Cumulative Returns', fontsize=14)
plt.xlabel('Year', fontsize=14)

# Plot the grid lines
plt.grid(which="major", color='k', linestyle='-.', linewidth=0.5)
plt.show()

# %% [markdown]
# ## Minute level data
#
# Following values are supported in the interval: 1m, 5m, 15m, 30m, 60m.

# %%
data = yf.download(tickers="MSFT", period="5d", interval="1m")

# Print the data
print(data.tail())
# Out:
# [*********************100%***********************]  1 of 1 completed
#                                  Open        High         Low       Close  \
# Datetime
# 2023-06-26 15:14:00-04:00  329.980011  330.005005  329.885010  329.920013
# 2023-06-26 15:15:00-04:00  329.934998  330.010010  329.884888  329.899994
# 2023-06-26 15:16:00-04:00  329.880005  329.880005  329.690002  329.720001
# 2023-06-26 15:17:00-04:00  329.730011  329.750000  329.609985  329.701294
# 2023-06-26 15:18:00-04:00  329.859985  329.859985  329.859985  329.859985
#
#                             Adj Close  Volume
# Datetime
# 2023-06-26 15:14:00-04:00  329.920013   18524
# 2023-06-26 15:15:00-04:00  329.899994   18618
# 2023-06-26 15:16:00-04:00  329.720001   39722
# 2023-06-26 15:17:00-04:00  329.701294   26967
# 2023-06-26 15:18:00-04:00  329.859985       0

# %%
# Read and print the stock tickers that make up S&P500
tickers = pd.read_html(
    'https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')[0]
print(tickers.head())

# Get the data for this tickers from yahoo finance
data = yf.download(tickers.Symbol.to_list(),'2021-1-1','2021-7-12', auto_adjust=True)['Close']
print(data.head())
# Out:
#   Symbol     Security             GICS Sector               GICS Sub-Industry  \
# 0    MMM           3M             Industrials        Industrial Conglomerates
# 1    AOS  A. O. Smith             Industrials               Building Products
# 2    ABT       Abbott             Health Care           Health Care Equipment
# 3   ABBV       AbbVie             Health Care                 Pharmaceuticals
# 4    ACN    Accenture  Information Technology  IT Consulting & Other Services
#
#      Headquarters Location  Date added      CIK      Founded
# 0    Saint Paul, Minnesota  1957-03-04    66740         1902
# 1     Milwaukee, Wisconsin  2017-07-26    91142         1916
# 2  North Chicago, Illinois  1957-03-04     1800         1888
# 3  North Chicago, Illinois  2012-12-31  1551152  2013 (1888)
# 4          Dublin, Ireland  2011-07-06  1467373         1989
# [*********************100%***********************]  503 of 503 completed
# 4 Failed downloads:
# ['BF.B']: Exception('%ticker%: No price data found, symbol may be delisted (1d 2021-1-1 -> 2021-7-12)')
# ['BRK.B']: Exception('%ticker%: No timezone found, symbol may be delisted')
# ['CEG', 'GEHC']: Exception("%ticker%: Data doesn't exist for startDate = 1609477200, endDate = 1626062400")
#                               A    AAL         AAP        AAPL       ABBV  \
# Date
# 2021-01-04 00:00:00  117.039719  15.13  147.685043  127.503639  95.027634
# 2021-01-05 00:00:00  117.996635  15.43  147.525513  129.080063  96.010277
# 2021-01-06 00:00:00  121.232399  15.52  156.048325  124.735039  95.180878
# 2021-01-07 00:00:00  124.458290  15.38  157.381195  128.991394  96.199585
# 2021-01-08 00:00:00  125.346130  15.13  159.624542  130.104736  96.704430
#
#                             ABC         ABT       ACGL         ACN  \
# Date
# 2021-01-04 00:00:00   93.312073  104.676422  34.900002  247.927536
# 2021-01-05 00:00:00   94.530449  105.971573  35.040001  249.338974
# 2021-01-06 00:00:00  102.662621  105.750931  36.580002  252.065125
# 2021-01-07 00:00:00  106.491806  106.777435  36.240002  254.443344
# 2021-01-08 00:00:00  106.395111  107.074829  36.439999  255.371368
#
#                            ADBE  ...        WYNN        XEL        XOM  \
# Date                             ...
# 2021-01-04 00:00:00  485.339996  ...  106.657669  61.130051  36.996006
# 2021-01-05 00:00:00  485.690002  ...  109.940208  60.534206  38.778950
# 2021-01-06 00:00:00  466.309998  ...  110.598709  61.874859  39.768478
# 2021-01-07 00:00:00  477.739990  ...  109.501205  60.664547  40.080490
# 2021-01-08 00:00:00  485.100006  ...  108.782837  61.223160  40.526226
#
#                           XRAY         XYL         YUM         ZBH  \
# Date
# 2021-01-04 00:00:00  52.413235   96.855476  101.172737  145.996872
# 2021-01-05 00:00:00  53.914936   96.738876  101.182289  148.522934
# 2021-01-06 00:00:00  56.518536  100.819450  101.736816  152.755280
# 2021-01-07 00:00:00  56.225998  105.395546  100.962372  151.849716
# 2021-01-08 00:00:00  56.733070  104.326813  102.444313  151.516098
#
#                            ZBRA       ZION         ZTS
# Date
# 2021-01-04 00:00:00  378.130005  39.725563  160.784653
# 2021-01-05 00:00:00  380.570007  40.354809  161.905090
# 2021-01-06 00:00:00  394.820007  44.889053  164.283600
# 2021-01-07 00:00:00  409.100006  46.258587  164.136185
# 2021-01-08 00:00:00  405.470001  45.083382  165.227112
#
# [5 rows x 503 columns]
